# %% [markdown]
# ### Informe final

# %% [markdown]
# A continuación procedo a describir los pasos que se llevaron a cabo para el análisis del dataset así como los resultados obtenidos e inconvenientes presentados.

# %% [markdown]
# ### EDA

# %% [markdown]
# En el EDA se hicieron todos los pasos necesarios para tener un dataset limpio y consistente tanto en la información como el tipo de dato.
#
# - Se verificaron valores inapropiados
#
# - Se hizo análisis de valores nulos y tipos de datos
#
# - Se hizo análisis de valores duplicados
#
# - Se verificó que no hubiera inconsistencias en las variables categoricas

# %% [markdown]
# ### Ingeniería de caracteristicas

# %% [markdown]
# Se añadieron variables nuevas que permitieran obtener información relevante de los datos, estas fueron:
#
# - Age
#
# - Total_Children
#
# - Total_Spend

# %% [markdown]
# ### Visualizaciones

# %% [markdown]
# El objetivo de este paso era obtener algunos insights valiosos que permitieran obtener una visión global de la información que se estaba manejando.

# %% [markdown]
# ### Distribución de la edad

# %% [markdown]
# Lo primero que hice fue ver la distribución de la edad para entender los rangos de edades de los clientes. Como se muestra en el siguiente gráfico estamos tratando con gente muy mayor donde la mayoria está en un rango deedadde entre 40 y 70 años.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ingresos vs Gasto en Vinos

# %% [markdown]
# Quice hacer esta comparación para analizar como influye los ingresos en la compra del vino que no es algo esencial denro de la canasta familiar. En el gráfico se puede ver que las personas de bajos ingresos no gastan mucho dinero en vino pero a partir de cierta cantidad de ingresos el gasto en vino aumenta y vemos como para algunas personas con muchos ingresos el vino no es de su preferencia y gastan muy poco.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Número de hijos vs gasto total

# %% [markdown]
# Aquí quise analizar como influye lacantidad de hijos en el gasto de productos y como vemos en el grafico hay una relación indirecta entre el número de hijos y los gastos lo cual result peculiar.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Estado Civil vs Ingresos

# %% [markdown]
# Acá quise analizar como influye el estado civil en el poder adquisitvo de las personas y como se ve en la gráfica en terminos generales estar solo o tener pareja no hace la diferencia a excepción del grupo absurd que tienen un rango de ingresos por encima de la mayoría.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Métodos de compra

# %% [markdown]
# Aquí quise analizar cuales son los canales de compra preferidos porlos clientes encontrando que elcanal preferido es la compra en tiendas lo cual no sorprende teniendo en cuenta el publico con el que se trata que es gente mayor.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Análisis no supervisado

# %% [markdown]
# Para el analisis no supervisado usamos k-means y para determinar el número óptimo de cluster usamos el método del codo. Como se muestra en la gráfica el punto dond los cambios en la pendiente no son tan abruptos es el punto 8 que precismente el número de clusters que seleccionamos.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Después de aplicar el K-means agrupamos el df por cluster y por promedio de caracteristicas, luego se realizo un heatmap para obtener una visión global del perfil de cada cluster.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# También se analizó el número de clientes por cada cluster

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Analisis final de clusters

# %% [markdown]
# Con todo lo anterior se construyó un perfil de cliente para cluster como se resume a continuación:

# %% [markdown]
# **Cluster 0**
#
# - Ingresos bajos (45,652) comparado con otros grupos.
# - Baja cantidad de hijos adolescentes (0.7) y casi ningún niño.
# - Gasto bajo en todos los productos, particularmente en vinos y productos de carne.
# - Tienden a comprar en tienda física y en línea pero muy poco en cátalogo
# - Edad avanzada (62 años).
#
# **Cluster 1**
#
# - Ingresos altos (73,389) y recencia moderada (41 días).
# - Gran gasto en vinos, productos cárnicos y otros productos de lujo (62 en productos de oro, 984 en vinos).
# - Pocas responsabilidades familiares (0.09 niños).
# - Tienen actividad de compra similar en todos los canales
# - Edad promedio (56 años).
#
# **Cluster 2**
#
# - Ingresos altos (78,948) con muy baja cantidad de hijos.
# - Gasto elevado en casi todas las categorías, con especial enfoque en carnes y productos de lujo.
# - Tambien compran en todos los canales pero compran más en catálogo que en la web
# - Edad promedio (53 años).
#
# **Cluster 3**
#
# - Ingresos más altos (79,698) con mínimos hijos.
# - Gasto similar al Cluster 2, pero ligeramente menor en productos de carne.
# - Sus compras en los canales es muy similar al cluster 2
# - Edad avanzada (57 años).
#
# **Cluster 4**
#
# - Ingresos bajos (41,076) y alto número de hijos (1.08 niños, 1.04 adolescentes).
# - Gasto extremadamente bajo en todos los productos.
# - Sus compras en los canales son muy bajas y se explica por lo bajo de sus ingresos
# - Edad media (59 años).
#
# **Cluster 5**
#
# - Ingresos moderados (65,559) con algún nivel de responsabilidad familiar (0.12 niños, 0.83 adolescentes).
# - Gasto elevado en productos de lujo (85 en productos de oro) y un gasto moderado en vinos (424).
# - Compran principalmente en tienda y web aunque también lo hacen en menor medida en catálogo.
# - Edad media (56 años).
#
# **Cluster 6**
#
# - Ingresos muy bajos (29,611) y alta cantidad de niños (0.91).
# - Gasto extremadamente bajo en todas las categorías.
# - Compra en los canales muy baja debido a quetambién tienen los ingresos más bajos
# - Edad más joven (44 años).
#
# **Cluster 7**
#
# - Ingresos medios (58,049) y cantidad moderada de hijos (1 niño, 1 adolescente).
# - Gasto elevado en vinos (524) y moderado en productos de lujo.
# - Tienen una tendenciafuerte de comprar en tienda y web
# - Edad avanzada (59 años).
#
# **Resumen General**
#
# - **Clusters 1, 2 y 3:** Se identifican como los clusters con ingresos altos y con un alto gasto en productos de lujo.
# - **Clusters 0, 4 y 6:** Representan a personas de ingresos bajos con un gasto muy limitado en productos.
# - **Clusters 5 y 7:** Son de ingresos medios y tienen un interés en productos de lujo, especialmente en vinos.

# %% [markdown]
# ### MLP

# %% [markdown]
# Respecto al MLP se trabajó con varias arquitecturas, estocon el fin de buscar los mejores resultados.Al momento de entrega de este trabajo está fue la última arquitectura con la que se estaba trabajando y sus caracteristicas:

# %% [markdown]
# - **Capas ocultas:** 2 capas densas con 64 neuronas cada una, con regularización L2 y activación Leaky ReLU.
#
# - **Función de activación de salida:** Sigmoide para clasificación binaria.
#
# - **Regularización:** L2 y Dropout para evitar sobreajuste.
#
# - **Optimización:** Adam como optimizador y binary_crossentropy como función de pérdida.
#
# - **Early Stopping:** Para detener el entrenamiento cuando la pérdida de validación deje de mejorar.

# %% [markdown]
# ### Evaluación del modelo

# %% [markdown]
# Con la anterior arquitectura se obtuvieron los siguientes resultados:

# %% [markdown]
# ### Matriz de cofusión

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 372 verdaderos negativos (VN): El modelo predijo correctamente 372 veces que las muestras pertenecían a la clase 0.
#
# - 9 falsos positivos (FP): El modelo predijo clase 0 incorrectamente 9 veces cuando en realidad pertenecían a la clase 1.
#
# - 47 falsos negativos (FN): El modelo no logró identificar 47 muestras que eran de la clase 1 y las predijo como clase 0.
#
# - 20 verdaderos positivos (VP): El modelo predijo correctamente la clase 1 solo 20 veces.

# %% [markdown]
# ### Precisión Recall y F1-Score

# %% [markdown]
# **Clase 0**
#
# - Precisión (0.89): De todas las predicciones hechas por el modelo como clase 0, el 89% fueron correctas.
#
# - Recall (0.98): El modelo fue capaz de identificar correctamente el 98% de las muestras que realmente eran de la clase 0.
#
# - F1-Score (0.93): Al ser una relación dela precisión con el recall su valor altoes esperado.
#
#
# **Clase 1**
#
# - Precisión (0.69): El modelo identificó correctamente el 69% de los ejemplos que predijo como clase 1.
#
# - Recall (0.30): Sin embargo, solo logró capturar el 30% de las muestras reales de la clase 1. Esto significa que el modelo tiene dificultades para identificar correctamente la clase 1, lo cual puede ser un problema de desequilibrio de clases.
#
# - F1-Score (0.42): Al tener un recall bajo el resultado no es el esprado

# %% [markdown]
# ### Curvas de aprendizaje

# %% [markdown]
# A continuación se muestran las curvas de aprendizaje.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# - Del EDA obtuvimos información importante sobrela distribución de la edad de los clientes y la relación del gasto de acuerdo al número de hijos.
#
# - Del análsis no supervisado obtuvimos cirtosclusters que nos permitió tener ciertos perfiles de cliente que describen sus comportamientos y preferencias de consumo de acuerdo con su poder adquisitvo y la relación que tiene con el número de hijos. Lainformaciónque se obtuvo fue importante y permite hacer una segmentación de los clientes para futuras campañas.
#
# - Respecto del MLP podemos decir que el modelo tiene un buen rendimiento en la clase mayoritaria (clase 0), pero tiene dificultades para identificar correctamente las muestras de la clase minoritaria (clase 1), como lo muestra su bajo recall y F1-score.
#
# - El hecho de que haya muchas más muestras de la clase 0 que de la clase 1 afecta el rendimiento del modelo
#
# - El modelo se puede seguir mejorando paramejorar el rendimiento de la clase 1 probando con diferentes parametros en la arquitectur que nos permita aumentar su recall y f1 score.
